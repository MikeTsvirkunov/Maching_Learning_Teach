# %% [markdown]
# # Импорт

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Загружаем DataSet

# %%
models = pd.read_csv('../../Data/DataLaba2/neo_task_smoted.csv').drop('hazardous', axis=1)[0:20]
models
# Out:
#     est_diameter_max  relative_velocity  miss_distance  absolute_magnitude
# 0          -0.999187          -0.528599      -0.972789            0.407593
# 1          -0.998421          -0.935292      -0.126239            0.290780
# 2          -0.997101          -0.534989       0.748307            0.182311
# 3          -0.999016          -0.650926      -0.663033            0.374218
# 4          -0.992669          -0.430407       0.906601            0.015436
# 5          -0.997594          -0.841794      -0.238846            0.215686
# 6          -0.993908          -0.636964      -0.086066            0.048811
# 7          -0.998918          -0.680206      -0.290704            0.357530
# 8          -0.988363          -0.716762       0.516203           -0.068002
# 9          -0.987237          -0.527128       0.651186           -0.084689
# 10         -0.997809          -0.772614      -0.825710            0.232374
# ...

# %%
models.to_csv('../../Data/DataLaba2/neo_task_for_pred.csv', index=False)
