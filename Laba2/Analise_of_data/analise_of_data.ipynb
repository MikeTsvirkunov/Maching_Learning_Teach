# %% [markdown]
# # Импорт

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.gridspec as gridspec

# %% [markdown]
# # Загрузите датасет для регрессии, выделите целевой признак и предикторы.
# <b>Целевой признак</b>: Appliances

# %% [markdown]
# - Tdewpoint - точка россы
# - Windspeed - скорость ветра
# - Press_mm_hg - давление мм/рт.ст.
# - absolute_magnitude - абсолютная звёздная величина
# - Appliances - прибор (применение)
# -

# %%
models = pd.read_csv('../../Data/neo_task.csv')
models
# Out:
#                id          name  est_diameter_min  est_diameter_max  \
# 0       3561024.0    (2011 GZ2)          0.016016          0.035813
# 1      54016766.0    (2020 HT6)          0.030518          0.068240
# 2       3746620.0  (2016 ED156)          0.055533          0.124177
# 3       3633054.0    (2013 FD8)          0.019256          0.043057
# 4       3742124.0   (2016 CW31)          0.139494          0.311918
# ...           ...           ...               ...               ...
# 90831  54231436.0     (2021 YE)          0.017561          0.039268
# 90832   3824972.0     (2018 KL)          0.110804          0.247765
# 90833   3740101.0  (2016 AB166)          0.035039          0.078350
# 90834   3691093.0  (2014 SQ260)          0.044112          0.098637
# 90835   3600600.0    (2012 EQ3)          0.084441          0.188817
#
#        relative_velocity  miss_distance  absolute_magnitude  hazardous
# 0           56014.078517   1.024333e+06               26.10      False
# 1            7864.348060   3.268186e+07               24.70      False
# 2           55257.544508   6.538636e+07               23.40      False
# 3           41531.404722   1.260796e+07               25.70      False
# 4           67639.394481   7.130590e+07               21.40      False
# ...                  ...            ...                 ...        ...
# 90831       23264.740825   1.635007e+06               25.90      False
# 90832       24802.519406   3.351901e+07               21.90      False
# 90833      116288.999548   5.471396e+07               24.40      False
# 90834       45763.317060   2.694877e+07               23.90      False
# 90835       79519.526381   3.631207e+07               22.49      False
#
# [90836 rows x 8 columns]

# %%
print(*(f'{i}: {len(models[i].unique())}' for i in  models.columns), sep='\n')
# Out:
# id: 27353
# name: 27419
# est_diameter_min: 1638
# est_diameter_max: 1638
# relative_velocity: 90272
# miss_distance: 90536
# absolute_magnitude: 1638
# hazardous: 2

# %%
models['hazardous'].unique()
# Out:
# array([False,  True])

# %%
same_names = models['name'].value_counts()
same_names
# Out:
# 277810 (2006 FV35)               43
# 469219 Kamo`oalewa (2016 HO3)    43
# (2016 CA138)                     40
# 138175 (2000 EE104)              39
# (2019 XS)                        38
#                                  ..
# (2004 FH29)                       1
# (2002 EW11)                       1
# (2015 CA1)                        1
# (2010 DK)                         1
# (2021 YE)                         1
# Name: name, Length: 27418, dtype: int64

# %%
same_id = models['id'].value_counts()
same_id
# Out:
# 2469219.0     43
# 2277810.0     43
# 3743123.0     39
# 3893865.0     38
# 2138175.0     38
#               ..
# 3720894.0      1
# 2415267.0      1
# 3557878.0      1
# 3843802.0      1
# 54231436.0     1
# Name: id, Length: 27352, dtype: int64

# %%
models.loc[models['id']==2469219]
# Out:
#               id                           name  est_diameter_min  \
# 338    2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 2966   2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 4461   2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 6523   2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 6599   2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 7393   2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 12602  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 14976  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 15572  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 15863  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 22557  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 24736  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 28081  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 30734  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 32354  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 36462  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 38970  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 39862  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 40013  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 42833  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 43459  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 48306  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 50008  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 51017  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 55512  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 57161  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 58328  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 58543  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 59602  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 60075  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 68850  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 69002  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 69967  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 70371  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 70530  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 72465  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 76368  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 76842  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 77588  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 79235  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 79438  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 86299  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
# 87838  2469219.0  469219 Kamo`oalewa (2016 HO3)          0.036187
#
#        est_diameter_max  relative_velocity  miss_distance  absolute_magnitude  \
# 338            0.080917       11345.529263   2.427898e+07               24.33
# 2966           0.080917       15045.754038   2.170340e+07               24.33
# 4461           0.080917       15218.964906   2.079695e+07               24.33
# 6523           0.080917       15445.788159   1.663276e+07               24.33
# 6599           0.080917       14568.309190   2.333365e+07               24.33
# 7393           0.080917       11116.485949   2.427107e+07               24.33
# 12602          0.080917       15445.978808   1.880784e+07               24.33
# 14976          0.080917       15304.364549   1.904591e+07               24.33
# 15572          0.080917       15592.784770   2.262092e+07               24.33
# 15863          0.080917       15439.983751   1.674039e+07               24.33
# 22557          0.080917       15860.941084   2.297678e+07               24.33
# 24736          0.080917       15413.191443   1.660018e+07               24.33
# 28081          0.080917       12484.983999   2.431541e+07               24.33
# 30734          0.080917       16229.052494   2.119409e+07               24.33
# 32354          0.080917       12576.912205   2.429435e+07               24.33
# 36462          0.080917       14629.980565   2.383909e+07               24.33
# 38970          0.080917       13941.677219   2.399064e+07               24.33
# 39862          0.080917       15351.287259   1.829475e+07               24.33
# 40013          0.080917       11690.152156   2.431140e+07               24.33
# 42833          0.080917       10742.416563   2.422251e+07               24.33
# 43459          0.080917       14582.071733   2.365028e+07               24.33
# 48306          0.080917       13225.046959   2.420357e+07               24.33
# 50008          0.080917       15132.273552   2.318956e+07               24.33
# 51017          0.080917       15446.778681   1.754131e+07               24.33
# 55512          0.080917       11856.941523   2.431466e+07               24.33
# 57161          0.080917       15386.279963   1.680122e+07               24.33
# 58328          0.080917       10871.158587   2.424747e+07               24.33
# 58543          0.080917       15925.697564   2.195501e+07               24.33
# 59602          0.080917       15382.529101   2.032125e+07               24.33
# 60075          0.080917       13260.624583   2.424962e+07               24.33
# 68850          0.080917       10868.812708   2.423005e+07               24.33
# 69002          0.080917       15384.556894   1.712776e+07               24.33
# 69967          0.080917       15334.830488   2.105350e+07               24.33
# 70371          0.080917       14221.998286   2.404398e+07               24.33
# 70530          0.080917       15464.296154   1.954735e+07               24.33
# 72465          0.080917       15495.759121   1.812412e+07               24.33
# 76368          0.080917       13757.417465   2.464646e+07               24.33
# 76842          0.080917       13963.527790   2.409758e+07               24.33
# 77588          0.080917       14824.360122   2.254455e+07               24.33
# 79235          0.080917       15293.065605   1.989437e+07               24.33
# 79438          0.080917       15285.830876   2.345715e+07               24.33
# 86299          0.080917       15469.233351   1.704627e+07               24.33
# 87838          0.080917       15404.809059   1.763275e+07               24.33
#
#        hazardous
# 338        False
# 2966       False
# 4461       False
# 6523       False
# 6599       False
# 7393       False
# 12602      False
# 14976      False
# 15572      False
# 15863      False
# 22557      False
# 24736      False
# 28081      False
# 30734      False
# 32354      False
# 36462      False
# 38970      False
# 39862      False
# 40013      False
# 42833      False
# 43459      False
# 48306      False
# 50008      False
# 51017      False
# 55512      False
# 57161      False
# 58328      False
# 58543      False
# 59602      False
# 60075      False
# 68850      False
# 69002      False
# 69967      False
# 70371      False
# 70530      False
# 72465      False
# 76368      False
# 76842      False
# 77588      False
# 79235      False
# 79438      False
# 86299      False
# 87838      False

# %% [markdown]
# # Выявляем кореляцию

# %%
fig, ax = plt.subplots(figsize=(8,8))  
fig = sns.heatmap(models.corr(method='pearson'), annot=True, annot_kws={"fontsize":12}).get_figure()

# %%
fig, ax = plt.subplots(figsize=(8,8))  
fig = sns.heatmap(models.corr(method='spearman'), annot=True, annot_kws={"fontsize":12}).get_figure()

# %% [markdown]
# # Проверим некоторые зависимости.

# %%
plt.plot(models['absolute_magnitude'], models['est_diameter_min'], 'bo', markersize=1)

# %%
plt.plot(models['est_diameter_min'], models['est_diameter_max'], 'bo', markersize=1)
