# %% [markdown]
# # Импорт

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Загружаем DataSet

# %%
df = pd.read_csv('../../Data/neo_task_moded_removed_nan.csv')
df
# Out:
#                id          name  est_diameter_min  est_diameter_max  \
# 0       3561024.0    (2011 GZ2)          0.016016          0.035813
# 1      54016766.0    (2020 HT6)          0.030518          0.068240
# 2       3746620.0  (2016 ED156)          0.055533          0.124177
# 3       3633054.0    (2013 FD8)          0.019256          0.043057
# 4       3742124.0   (2016 CW31)          0.139494          0.311918
# ...           ...           ...               ...               ...
# 88535  54231436.0     (2021 YE)          0.017561          0.039268
# 88536   3824972.0     (2018 KL)          0.110804          0.247765
# 88537   3740101.0  (2016 AB166)          0.035039          0.078350
# 88538   3691093.0  (2014 SQ260)          0.044112          0.098637
# 88539   3600600.0    (2012 EQ3)          0.084441          0.188817
#
#        relative_velocity  miss_distance  absolute_magnitude  hazardous
# 0           56014.078517   1.024333e+06               26.10      False
# ...

# %% [markdown]
# # Удаляем name, id

# %%
df = df.drop(['name', 'id'], axis=1)

# %% [markdown]
# ## Сохранение

# %%
df.to_csv('../../Data/neo_task_moded_removed_nan_removed_useless_params.csv', index=False)
