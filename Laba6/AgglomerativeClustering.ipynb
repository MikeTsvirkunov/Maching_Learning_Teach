# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib.gridspec as gridspec
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import rand_score, adjusted_rand_score

from joblib import dump

# %% [markdown]
# # Data1

# %%
data1 = pd.read_csv('../Data/DataLaba6/data1.csv')
x1 = (data1.drop('class', axis=1)).to_numpy()
y1 = data1['class'].to_numpy()

# %%
ss = []
for i in range(2, 11):
    ss.append(silhouette_score(x1, AgglomerativeClustering(n_clusters=i).fit_predict(x1)))
plt.plot(ss)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x135379be910>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
from sklearn.metrics.pairwise import PAIRED_DISTANCES
print(PAIRED_DISTANCES)
agclust1 = AgglomerativeClustering(n_clusters=2, linkage='complete', affinity='cosine').fit(x1)
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x1[:, 0], x1[:, 1], c=agclust1.labels_)
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x1[:, 0], x1[:, 1], c=y1)
# Out:
# {'cosine': <function paired_cosine_distances at 0x00000135328B1F70>, 'euclidean': <function paired_euclidean_distances at 0x00000135328B1E50>, 'l2': <function paired_euclidean_distances at 0x00000135328B1E50>, 'l1': <function paired_manhattan_distances at 0x00000135328B1EE0>, 'manhattan': <function paired_manhattan_distances at 0x00000135328B1EE0>, 'cityblock': <function paired_manhattan_distances at 0x00000135328B1EE0>}
# c:\Users\Mike\Desktop\4semak\Maching_learning\Maching_Learning\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %% [markdown]
# # Data2

# %%
data2 = pd.read_csv('../Data/DataLaba6/data2.csv')
x2 = (data2.drop('class', axis=1)).to_numpy()
y2 = data2['class'].to_numpy()

# %%
ss = []
for i in range(2, 11):
    ss.append(silhouette_score(x2, AgglomerativeClustering(n_clusters=i).fit_predict(x2)))
plt.plot(ss)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x15790db0ac0>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
agclust2 = AgglomerativeClustering(n_clusters=5).fit(x2)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x2[:, 0], x2[:, 1], c=agclust2.labels_)
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x2[:,0], x2[:,1], c=y2)

# %% [markdown]
# # Data 3

# %%
data3 = pd.read_csv('../Data/DataLaba6/data3.csv')
x3 = (data3.drop('class', axis=1)).to_numpy()
y3 = data3['class'].to_numpy()

# %%
ss = []
for i in range(2, 21):
    ss.append(silhouette_score(x3, AgglomerativeClustering(n_clusters=i).fit_predict(x3)))
plt.plot(ss)
plt.xticks(range(0, 19), range(2, 21))
# Out:
# ([<matplotlib.axis.XTick at 0x15790f1beb0>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10'),
#   Text(9, 0, '11'),
#   Text(10, 0, '12'),
#   Text(11, 0, '13'),
#   Text(12, 0, '14'),
#   Text(13, 0, '15'),
#   Text(14, 0, '16'),
#   Text(15, 0, '17'),
#   Text(16, 0, '18'),
#   Text(17, 0, '19'),
#   Text(18, 0, '20')])

# %%
dbscan3 = AgglomerativeClustering(n_clusters=7).fit(x3)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x3[:,0], x3[:,1], c=dbscan3.labels_)
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x3[:,0], x3[:,1], c=y3)
