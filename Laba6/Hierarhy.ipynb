# %%
from scipy.cluster import hierarchy
import matplotlib.gridspec as gridspec
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import rand_score, adjusted_rand_score

from joblib import dump

# %% [markdown]
# # Data1

# %%
data1 = pd.read_csv('../Data/DataLaba6/data1.csv')
x1 = (data1.drop('class', axis=1)).to_numpy()
y1 = data1['class'].to_numpy()

# %%
linked = hierarchy.linkage(x1, method='ward')

# %%
ss = []
for i in np.arange(2, 100):
    c = hierarchy.fcluster(linked, t=i, criterion='distance')
    nc = np.unique(c).shape[0]
    # print(i, nc)
    ss.append(silhouette_score(x1, c) if nc > 1 and nc < x1.shape[0]  else -1)
plt.plot(ss)
plt.axvline(15, color='red', linestyle='-')
# ss
# plt.xticks(range(0, 18), np.arange(0, 9, 0.5))

# %%
plt.figure(figsize=(8, 6))
hierarchy.dendrogram(linked)
plt.axhline(4.5, color='red', linestyle='--')
plt.axhline(6.4, color='red', linestyle=':')
plt.axhline(20, color='red', linestyle='-')

# %%
p1 = hierarchy.fcluster(hierarchy.linkage(x1, method="ward"), t=7.5, criterion='distance')
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x1[:, 0], x1[:, 1], c=p1)
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x1[:,0], x1[:,1], c=y1)

# %% [markdown]
# # Data2

# %%
data2 = pd.read_csv('../Data/DataLaba6/data2.csv')
x2 = (data2.drop('class', axis=1)).to_numpy()
y2 = data2['class'].to_numpy()

# %%
linked2 = hierarchy.linkage(x2, method='ward')

# %%
ss = []
for i in np.arange(2, 100):
    c = hierarchy.fcluster(linked2, t=i, criterion='distance')
    nc = np.unique(c).shape[0]
    # print(i, nc, c.shape, x2.shape)
    ss.append(silhouette_score(x2, c) if nc > 1 and nc < x2.shape[0]  else -1)
plt.plot(ss)
plt.axvline(15, color='red', linestyle='-')
# ss
# plt.xticks(range(0, 18), np.arange(0, 9, 0.5))

# %%
plt.figure(figsize=(8, 6))
hierarchy.dendrogram(linked)
plt.axhline(8, color='red', linestyle='--')
plt.axhline(70, color='red', linestyle=':')
plt.axhline(20, color='red', linestyle='-')

# %%
p1 = hierarchy.fcluster(hierarchy.linkage(x1, method="ward"), t=20, criterion='distance')

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x1[:, 0], x1[:, 1], c=p1)
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x1[:,0], x1[:,1], c=y1)

# %% [markdown]
# # Data 3

# %%
data3 = pd.read_csv('../Data/DataLaba6/data3.csv')
x3 = (data3.drop('class', axis=1)).to_numpy()
y3 = data3['class'].to_numpy()

# %%
linked3 = hierarchy.linkage(x3, method='ward')

# %%
ss = []
for i in np.arange(2, 100):
    c = hierarchy.fcluster(linked3, t=i, criterion='distance')
    nc = np.unique(c).shape[0]
    # print(i, nc)
    ss.append(silhouette_score(x3, c) if nc > 1 and nc < x3.shape[0]  else -1)
plt.plot(ss)
plt.axvline(18, color='red', linestyle='-')

# %%
plt.figure(figsize=(8, 6))
hierarchy.dendrogram(linked)
plt.axhline(35, color='red', linestyle='--')
plt.axhline(6, color='red', linestyle=':')
plt.axhline(18, color='red', linestyle='-')

# %%
p1 = hierarchy.fcluster(hierarchy.linkage(x1, method="ward"), t=20, criterion='distance')

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x1[:, 0], x1[:, 1], c=p1)
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x1[:,0], x1[:,1], c=y1)
