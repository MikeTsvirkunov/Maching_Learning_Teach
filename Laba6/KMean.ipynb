# %%
from sklearn.cluster import KMeans
import matplotlib.gridspec as gridspec
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_score

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import rand_score, adjusted_rand_score, fowlkes_mallows_score

from joblib import dump

# %% [markdown]
# # Data1

# %%
data1 = pd.read_csv('../Data/DataLaba6/data1.csv')
x1 = (data1.drop('class', axis=1)).to_numpy()
y1 = data1['class'].to_numpy()

# %%
inertias = []
for i in range(2, 11):
    km = KMeans(i, n_init='auto').fit(x1)
    inertias.append(km.inertia_)
plt.plot(inertias)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x2497e858130>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
ss = []
for i in range(2, 11):
    ss.append(silhouette_score(x1, KMeans(i, n_init='auto').fit(x1).labels_))
plt.plot(ss)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x2497e90d0a0>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
kmeans1 = KMeans(2, n_init='auto').fit(x1)
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x1[:,0], x1[:,1], c=kmeans1.labels_)
ax.scatter(kmeans1.cluster_centers_[:, 0],
           kmeans1.cluster_centers_[:, 1], s=100, c='red')
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x1[:,0], x1[:,1], c=y1)

# %%
rand_score(y1, kmeans1.labels_), adjusted_rand_score(y1, kmeans1.labels_), fowlkes_mallows_score(y1, kmeans1.labels_)
# Out:
# (0.869145728643216, 0.7382521987515392, 0.8726257250306807)

# %% [markdown]
# # Data2

# %%
data2 = pd.read_csv('../Data/DataLaba6/data2.csv')
x2 = (data2.drop('class', axis=1)).to_numpy()
y2 = data2['class'].to_numpy()

# %%
inertias = []
for i in range(2, 11):
    km = KMeans(i, n_init='auto').fit(x2)
    inertias.append(km.inertia_)
plt.plot(inertias)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x249006ccc10>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
ss = []
for i in range(2, 11):
    ss.append(silhouette_score(x2, KMeans(i, n_init='auto').fit(x2).labels_))
plt.plot(ss)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x249003da550>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
kmeans2 = KMeans(5, n_init='auto').fit(x2)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x2[:,0], x2[:,1], c=kmeans2.labels_)
ax.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 1], s=100, c='red')
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x2[:,0], x2[:,1], c=y2)

# %%
rand_score(y2, kmeans2.labels_), adjusted_rand_score(y2, kmeans2.labels_), fowlkes_mallows_score(y2, kmeans2.labels_)
# Out:
# (0.9973511407902059, 0.9916809060682668, 0.993333708353757)

# %% [markdown]
# ## What if

# %%
kmeans2_with_4 = KMeans(4, n_init='auto').fit(x2)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)

gs = gridspec.GridSpec(1, 2)

ax = fig.add_subplot(gs[0, 0])
ax.scatter(x2[:, 0], x2[:, 1], c=kmeans2_with_4.labels_)
ax.scatter(kmeans2_with_4.cluster_centers_[:, 0], kmeans2_with_4.cluster_centers_[:, 1], s=100, c='red')

ax = fig.add_subplot(gs[0, 1])
ax.scatter(x2[:,0], x2[:,1], c=y2)

# %%
rand_score(y2, kmeans2_with_4.labels_), adjusted_rand_score(y2, kmeans2_with_4.labels_), fowlkes_mallows_score(y2, kmeans2_with_4.labels_)
# Out:
# (0.9192042292710072, 0.7794206070842893, 0.8423286472644358)

# %% [markdown]
# # Data 3

# %%
data3 = pd.read_csv('../Data/DataLaba6/data3.csv')
x3 = (data3.drop('class', axis=1)).to_numpy()
y3 = data3['class'].to_numpy()

# %%
inertias = []
for i in range(2, 11):
    km = KMeans(i, n_init='auto').fit(x3)
    inertias.append(km.inertia_)
plt.plot(inertias)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x2ca2a2ab1f0>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
ss = []
for i in range(2, 11):
    ss.append(silhouette_score(x3, KMeans(i, n_init='auto').fit(x3).labels_))
plt.plot(ss)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x2ca2bd011c0>,
# ...
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
kmeans3 = KMeans(10, n_init='auto').fit(x3)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x3[:,0], x3[:,1], c=kmeans3.labels_)
ax.scatter(kmeans3.cluster_centers_[:,0], kmeans3.cluster_centers_[:,1], s=100, c='red')
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x3[:,0], x3[:,1], c=y3)

# %%
rand_score(y3, kmeans3.labels_), adjusted_rand_score(y3, kmeans3.labels_), fowlkes_mallows_score(y3, kmeans3.labels_)
# Out:
# (0.9641206030150754, 0.8035543437985633, 0.8249450992230506)

# %% [markdown]
# # What if

# %%
kmeans3_8 = KMeans(8, n_init='auto').fit(x3)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x3[:,0], x3[:,1], c=kmeans3_8.labels_)
ax.scatter(kmeans3_8.cluster_centers_[:,0], kmeans3_8.cluster_centers_[:,1], s=100, c='red')
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x3[:,0], x3[:,1], c=y3)

# %%
rand_score(y3, kmeans3_8.labels_), adjusted_rand_score(y3, kmeans3_8.labels_), fowlkes_mallows_score(y3, kmeans3_8.labels_)
# Out:
# (0.9346231155778895, 0.6987195823718273, 0.7528053220215769)
