# %%
from sklearn.cluster import KMeans
import matplotlib.gridspec as gridspec
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, RocCurveDisplay, auc

from joblib import dump

# %% [markdown]
# # Data1

# %%
data1 = pd.read_csv('../Data/DataLaba6/data1.csv')
x1 = (data1.drop('class', axis=1)).to_numpy()
y1 = data1['class'].to_numpy()

# %%
kmeans1 = KMeans(3, n_init='auto').fit(x1)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x1[:,0], x1[:,1], c=kmeans1.labels_)
ax.scatter(kmeans1.cluster_centers_[:, 0],
           kmeans1.cluster_centers_[:, 1], s=100, c='red')
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x1[:,0], x1[:,1], c=y1)

# %% [markdown]
# ## What if

# %%
inertias = []
for i in range(2, 11):
    km = KMeans(i, n_init='auto').fit(x1)
    inertias.append(km.inertia_)
plt.plot(inertias)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x1ad4d0c9100>,
#   <matplotlib.axis.XTick at 0x1ad4d0c90d0>,
#   <matplotlib.axis.XTick at 0x1ad4d0bfca0>,
#   <matplotlib.axis.XTick at 0x1ad4d0a33d0>,
#   <matplotlib.axis.XTick at 0x1ad4d0f67f0>,
#   <matplotlib.axis.XTick at 0x1ad4d0fd880>,
#   <matplotlib.axis.XTick at 0x1ad4d0f6520>,
#   <matplotlib.axis.XTick at 0x1ad4d0fdfd0>,
#   <matplotlib.axis.XTick at 0x1ad4d1087f0>],
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
ss = []
for i in range(2, 11):
    ss.append(silhouette_score(x1, KMeans(i, n_init='auto').fit(x1).labels_))
plt.plot(ss)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x1ad4d139a30>,
#   <matplotlib.axis.XTick at 0x1ad4d139a00>,
#   <matplotlib.axis.XTick at 0x1ad4d139610>,
#   <matplotlib.axis.XTick at 0x1ad4e713e20>,
#   <matplotlib.axis.XTick at 0x1ad4e71f820>,
#   <matplotlib.axis.XTick at 0x1ad4e71f040>,
#   <matplotlib.axis.XTick at 0x1ad4e71f6a0>,
#   <matplotlib.axis.XTick at 0x1ad4e726790>,
#   <matplotlib.axis.XTick at 0x1ad4e726f70>],
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %% [markdown]
# # Data2

# %%
data2 = pd.read_csv('../Data/DataLaba6/data2.csv')
x2 = (data2.drop('class', axis=1)).to_numpy()
y2 = data2['class'].to_numpy()

# %%
kmeans2 = KMeans(5, n_init='auto').fit(x2)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x2[:,0], x2[:,1], c=kmeans2.labels_)
ax.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 1], s=100, c='red')
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x2[:,0], x2[:,1], c=y2)

# %% [markdown]
# ## What if

# %%
inertias = []
for i in range(2, 11):
    km = KMeans(i, n_init='auto').fit(x2)
    inertias.append(km.inertia_)
plt.plot(inertias)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x1ad4e8537f0>,
#   <matplotlib.axis.XTick at 0x1ad4e8537c0>,
#   <matplotlib.axis.XTick at 0x1ad4e8533d0>,
#   <matplotlib.axis.XTick at 0x1ad4e830a00>,
#   <matplotlib.axis.XTick at 0x1ad4e87d910>,
#   <matplotlib.axis.XTick at 0x1ad4e887c10>,
#   <matplotlib.axis.XTick at 0x1ad4e892430>,
#   <matplotlib.axis.XTick at 0x1ad4e892c10>,
#   <matplotlib.axis.XTick at 0x1ad4e899430>],
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
ss = []
for i in range(2, 11):
    ss.append(silhouette_score(x2, KMeans(i, n_init='auto').fit(x2).labels_))
plt.plot(ss)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x1ad4ecdab80>,
#   <matplotlib.axis.XTick at 0x1ad4ecdab50>,
#   <matplotlib.axis.XTick at 0x1ad4ecda760>,
#   <matplotlib.axis.XTick at 0x1ad4e8b2fa0>,
#   <matplotlib.axis.XTick at 0x1ad4e8c19a0>,
#   <matplotlib.axis.XTick at 0x1ad4e8c1160>,
#   <matplotlib.axis.XTick at 0x1ad4e8c1640>,
#   <matplotlib.axis.XTick at 0x1ad4e8ad190>,
#   <matplotlib.axis.XTick at 0x1ad4e8c5880>],
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %% [markdown]
# # Data 3

# %%
data3 = pd.read_csv('../Data/DataLaba6/data3.csv')
x3 = (data3.drop('class', axis=1)).to_numpy()
y3 = data3['class'].to_numpy()

# %%
kmeans3 = KMeans(10, n_init='auto').fit(x3)

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(5)
fig.set_figwidth(15)
gs = gridspec.GridSpec(1, 2)
ax = fig.add_subplot(gs[0, 0])
ax.scatter(x3[:,0], x3[:,1], c=kmeans3.labels_)
ax.scatter(kmeans3.cluster_centers_[:,0], kmeans3.cluster_centers_[:,1], s=100, c='red')
ax = fig.add_subplot(gs[0, 1])
ax.scatter(x3[:,0], x3[:,1], c=y3)

# %% [markdown]
# # What if

# %%
inertias = []
for i in range(2, 11):
    km = KMeans(i, n_init='auto').fit(x3)
    inertias.append(km.inertia_)
plt.plot(inertias)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x1ad4ed44b50>,
#   <matplotlib.axis.XTick at 0x1ad4ed44b20>,
#   <matplotlib.axis.XTick at 0x1ad4ed44730>,
#   <matplotlib.axis.XTick at 0x1ad4e8fadf0>,
#   <matplotlib.axis.XTick at 0x1ad4ed71b20>,
#   <matplotlib.axis.XTick at 0x1ad4ed7ce50>,
#   <matplotlib.axis.XTick at 0x1ad4ed85670>,
#   <matplotlib.axis.XTick at 0x1ad4ed85e50>,
#   <matplotlib.axis.XTick at 0x1ad4ed8d670>],
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %%
ss = []
for i in range(2, 11):
    ss.append(silhouette_score(x3, KMeans(i, n_init='auto').fit(x3).labels_))
plt.plot(ss)
plt.xticks(range(0, 9), range(2, 11))
# Out:
# ([<matplotlib.axis.XTick at 0x1ad4edbeb80>,
#   <matplotlib.axis.XTick at 0x1ad4edbeb50>,
#   <matplotlib.axis.XTick at 0x1ad4edbe760>,
#   <matplotlib.axis.XTick at 0x1ad4edec970>,
#   <matplotlib.axis.XTick at 0x1ad4edec7f0>,
#   <matplotlib.axis.XTick at 0x1ad4edf5970>,
#   <matplotlib.axis.XTick at 0x1ad4edf57c0>,
#   <matplotlib.axis.XTick at 0x1ad4edec250>,
#   <matplotlib.axis.XTick at 0x1ad4ee007c0>],
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])
